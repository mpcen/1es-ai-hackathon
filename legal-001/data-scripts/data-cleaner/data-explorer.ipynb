# %%
! pip install pandas

import json 
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /home/mpcen/workspace/projects/web2/1es-hackathon/ai-model/.venv/lib/python3.9/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mpcen/workspace/projects/web2/1es-hackathon/ai-model/.venv/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/mpcen/workspace/projects/web2/1es-hackathon/ai-model/.venv/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/mpcen/workspace/projects/web2/1es-hackathon/ai-model/.venv/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /home/mpcen/workspace/projects/web2/1es-hackathon/ai-model/.venv/lib/python3.9/site-packages (from pandas) (1.25.1)
# Requirement already satisfied: six>=1.5 in /home/mpcen/workspace/projects/web2/1es-hackathon/ai-model/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ### Add indexes to keep and license name

# %%
indexes_to_keep = [

]

lic = 'MIT'

# %% [markdown]
# ### Preview data

# %%
df = pd.read_json("../model-trainer/final-data.json")
df
# Out:
#                                                     text          license
# 0      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# 1      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# 2      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# 3      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# 4      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# ...                                                  ...              ...
# 11213  APPLE PUBLIC SOURCE LICENSE\nVersion 2.0 -  Au...         APSL-2.0
# 11214  APPLE PUBLIC SOURCE LICENSE\nVersion 2.0 -  Au...         APSL-2.0
# 11215  APPLE PUBLIC SOURCE LICENSE\nVersion 2.0 -  Au...         APSL-2.0
# 11216  APPLE PUBLIC SOURCE LICENSE\nVersion 2.0 -  Au...         APSL-2.0
# 11217  APPLE PUBLIC SOURCE LICENSE\nVersion 2.0 -  Au...         APSL-2.0
#
# [11218 rows x 2 columns]

# %%
df_scoped = df.loc[df['license'] == lic]
df_scoped
# Out:
#                                                    text license
# 6612  MIT License Copyright (c) 2022 ruihua guan Per...     MIT
# 6613  (The MIT License) Copyright (c) 2011 Le Cong N...     MIT
# 6614  MIT License Copyright (c) 2022 ruihua guan Per...     MIT
# 6615  # The MIT License (MIT) Copyright (c) 2016 Jon...     MIT
# 6616  MIT License Copyright (c) 2020 Danelia Sanchez...     MIT
# ...                                                 ...     ...
# 6766  (The MIT License) Copyright (c) 2014 Tejesh Me...     MIT
# 6767  The MIT License (MIT) Copyright (c) 2016-prese...     MIT
# 6768  MIT License Copyright (C) 2012-present by fent...     MIT
# 6769  The MIT License (MIT) Copyright (c) 2016-prese...     MIT
# 6770  The MIT License (MIT) Copyright (c) 2016-prese...     MIT
#
# [159 rows x 2 columns]

# %% [markdown]
# ### Write the scoped data to a csv

# %%
df_scoped.to_csv(f"./explored-licenses/{lic}", sep='\t', encoding='utf-8')

# %% [markdown]
# ### Track indexes needed to be deleted from DF

# %%
indexes_to_delete = []

for index, row in df_scoped.iterrows():
    if index not in indexes_to_keep:
        indexes_to_delete.append(index)

indexes_to_delete
# Out:
# [6382,
#  6383,
#  6384,
#  6385,
#  6386,
#  6387,
#  6388,
#  6389,
#  6390,
#  6391,
#  6392,
#  6393,
#  6394,
#  6395,
#  6396,
#  6397,
#  6398,
#  6399,
#  6400,
#  6401,
#  6402,
#  6403,
#  6404,
#  6405,
#  6406,
#  6407,
#  6408,
#  6409,
#  6410,
#  6430,
#  6431,
#  6437,
#  6438]

# %% [markdown]
# ### Remove the indexes with bad data

# %%
df.drop(indexes_to_delete, axis=0, inplace=True)

# %% [markdown]
# ### Verify data

# %%
dict = df.to_dict(orient='records')

with open("final-data.json", "w") as outfile:
    json.dump(dict, outfile)

# %%
df = pd.read_json("final-data.json")
df_scoped = df.loc[df['license'] == lic]
df_scoped
# Out:
#                                                    text license
# 6382  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6383  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6384  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6385  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6386  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6387  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6388  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6389  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6390  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6391  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6392  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6393  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6394  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6395  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6396  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6397  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6398  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6399  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6400  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6401  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6402  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6403  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6404  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6405  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6406  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6407  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6408  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6409  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6410  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6411  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6412  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6413  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6414  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6415  The JSON License (JSON) Copyright (c) 2020-202...    JSON
# 6416  The JSON License (JSON) Copyright (c) 2020-202...    JSON

# %%
df
# Out:
#                                                     text          license
# 0      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# 1      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# 2      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# 3      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# 4      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# ...                                                  ...              ...
# 11213  APPLE PUBLIC SOURCE LICENSE\nVersion 2.0 -  Au...         APSL-2.0
# 11214  APPLE PUBLIC SOURCE LICENSE\nVersion 2.0 -  Au...         APSL-2.0
# 11215  APPLE PUBLIC SOURCE LICENSE\nVersion 2.0 -  Au...         APSL-2.0
# 11216  APPLE PUBLIC SOURCE LICENSE\nVersion 2.0 -  Au...         APSL-2.0
# 11217  APPLE PUBLIC SOURCE LICENSE\nVersion 2.0 -  Au...         APSL-2.0
#
# [11218 rows x 2 columns]
