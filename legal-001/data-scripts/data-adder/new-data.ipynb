# %%
import json
import pandas as pd

df = pd.read_json("../data-cleaning/final-data.json")
new_data_df = pd.read_json("new-data.json")

df = pd.concat([df, new_data_df], ignore_index=True)

dict = df.to_dict(orient='records')

with open("../data-cleaning/final-data.json", "w") as outfile:
    json.dump(dict, outfile)
    
df = pd.read_json("../data-cleaning/final-data.json")
df
# Out:
#                                                     text          license
# 0      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# 1      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# 2      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# 3      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# 4      Attribution-NonCommercial-NoDerivs 2.0 Copyrig...  CC-BY-NC-ND-2.0
# ...                                                  ...              ...
# 10928  MIT License Copyright (c) 2019 Rolando Santama...              MIT
# 10929  MIT License Copyright (c) 2019 Rolando Santama...              MIT
# 10930  MIT License Copyright (c) 2019 Rolando Santama...              MIT
# 10931  MIT License Copyright (c) 2019 Rolando Santama...              MIT
# 10932  MIT License Copyright (c) 2019 Rolando Santama...              MIT
#
# [10933 rows x 2 columns]
